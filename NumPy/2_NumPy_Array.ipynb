# %% [markdown]
# ## NumPy Arrays
#
# In NumPy, arrays are the main data structure. They are faster and more powerful than normal Python lists because they store elements of the same data type and support mathematical operations directly.

# %%
import numpy as np

arr = np.array([1, 2, 3, 4, 5])

print(arr)

print(type(arr))

## type(): This built-in Python function tells us the type of the object passed to it. Like in above code it shows that arr is numpy.ndarray type.

# %% [markdown]
# ### Dimensions in Arrays
#
# In NumPy, dimension means how many axes (directions) an array has.
# It is also called ndim (number of dimensions).

# %% [markdown]
# #### 1️⃣ 0-D Array (Scalar)
# A single value.

# %%
import numpy as np

arr = np.array(10)
print(arr)
print(arr.ndim)
# Out:
# 10
# 0

# %% [markdown]
# #### 2️⃣ 1-D Array
# A simple list of elements.

# %%
import numpy as np
arr = np.array([1, 2, 3, 4])
print(arr)
print(arr.ndim)
# Out:
# [1 2 3 4]
# 1

# %% [markdown]
# #### 3️⃣ 2-D Array
# Array of arrays (rows and columns).
# Looks like a matrix.

# %%
import numpy as np
arr = np.array([[1, 2], 
                [3, 4]])
print(arr)
print(arr.ndim)
# Out:
# [[1 2]
#  [3 4]]
# 2

# %% [markdown]
# #### 4️⃣ 3-D Array
# An array that has 2-D arrays (matrices) as its elements is called 3-D array.

# %%
import numpy as np

arr = np.array([[[1, 2, 3], [4, 5, 6]], [[1, 2, 3], [4, 5, 6]]])

print(arr)

# %% [markdown]
# #### Check Number of Dimensions?
# NumPy Arrays provides the ndim attribute that returns an integer that tells us how many dimensions the array have.

# %%
import numpy as np

a = np.array(42)
b = np.array([1, 2, 3, 4, 5])
c = np.array([[1, 2, 3], [4, 5, 6]])
d = np.array([[[1, 2, 3], [4, 5, 6]], [[1, 2, 3], [4, 5, 6]]])

print(a.ndim)
print(b.ndim)
print(c.ndim)
print(d.ndim)

# %% [markdown]
# #### Higher Dimensional Arrays
# An array can have any number of dimensions.
# When the array is created, you can define the number of dimensions by using the ndmin argument.

# %%
import numpy as np

arr = np.array([1, 2, 3, 4], ndmin=5)

print(arr)
print('number of dimensions :', arr.ndim)
